# %%
import numpy as np
import pandas as pd
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
print(pd.__doc__)
# Out:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
#   - Size mutability: columns can be inserted and deleted from DataFrame and
#     higher dimensional objects
#   - Automatic and explicit data alignment: objects can be explicitly aligned
# ...

# %%
# creating a synthentic student score data
col_name = ['CA1','CA2','CA3'] # column name = col_name
sit_no = np.arange(1,51)  # sit number array range from 1 to 50. The sit_no as row(index)
np.random.seed(2)   # using seed(2) to all have the same generated random numbers 
score = np.random.randint(1,11,150)   # score will be the generated random score between 1 and 10, for the 3 test 3*50=150 r score.
score =score.reshape(50,3)    # reshape it into 50 rows and 3 columns
student_score = pd.DataFrame(data = score, index=sit_no,columns=col_name)
student_score
# Out:
#     CA1  CA2  CA3
# 1     9    9    7
# 2     3    9    8
# 3     3    2    6
# 4     5    5    6
# 5     8    4    7
# 6     5    4    8
# 7     7    2    4
# 8     6    9    5
# 9     7    4   10
# 10    3    1    5
# 11    3    5    2
# 12    8    9    3
# 13   10    9    8
# 14    2    7    9
# 15    6   10   10
# 16   10    4    1
# 17    1    3    9
# 18    9    3   10
# 19    7    6    7
# 20    7    7    4
# 21    9    3    2
# 22    5    9    2
# 23    7   10    6
# 24    2    3    5
# 25    8    7    5
# 26    6    9    4
# 27    1    1    6
# 28    8    6    1
# 29    9    7    6
# 30    2    8    5
# 31    4    7    2
# 32    5    1    9
# 33    6    5    3
# 34   10    8    2
# 35   10    3    2
# 36    1    8    2
# 37    9   10    1
# 38    8    1    6
# 39    3    6    2
# 40    4    4    2
# 41    9    7    9
# 42    2    6    8
# 43    1   10    2
# 44    6   10    3
# 45    1    1    5
# 46    7    4    2
# 47    9    6   10
# 48    6    5    3
# 49    8    9    8
# ...

# %%
# selecting a single column from the dataFrame
student_score['CA3']
# Out:
# 1      7
# 2      8
# 3      6
# 4      6
# 5      7
# 6      8
# 7      4
# 8      5
# 9     10
# 10     5
# 11     2
# 12     3
# 13     8
# 14     9
# 15    10
# 16     1
# 17     9
# 18    10
# 19     7
# 20     4
# 21     2
# 22     2
# 23     6
# 24     5
# 25     5
# 26     4
# 27     6
# 28     1
# 29     6
# 30     5
# 31     2
# 32     9
# 33     3
# 34     2
# 35     2
# 36     2
# 37     1
# 38     6
# 39     2
# 40     2
# 41     9
# 42     8
# 43     2
# 44     3
# 45     5
# 46     2
# 47    10
# 48     3
# 49     8
# 50     9
# Name: CA3, dtype: int32

# %%
# selecting multiole columns from the DataFrame
student_score[['CA1','CA3']]
# Out:
#     CA1  CA3
# 1     9    7
# 2     3    8
# 3     3    6
# 4     5    6
# 5     8    7
# 6     5    8
# 7     7    4
# 8     6    5
# 9     7   10
# 10    3    5
# 11    3    2
# 12    8    3
# 13   10    8
# 14    2    9
# 15    6   10
# 16   10    1
# 17    1    9
# 18    9   10
# 19    7    7
# 20    7    4
# 21    9    2
# 22    5    2
# 23    7    6
# 24    2    5
# 25    8    5
# 26    6    4
# 27    1    6
# 28    8    1
# 29    9    6
# 30    2    5
# 31    4    2
# 32    5    9
# 33    6    3
# 34   10    2
# 35   10    2
# 36    1    2
# 37    9    1
# 38    8    6
# 39    3    2
# 40    4    2
# 41    9    9
# 42    2    8
# 43    1    2
# 44    6    3
# 45    1    5
# 46    7    2
# 47    9   10
# 48    6    3
# 49    8    8
# 50    4    9

# %%
# selecting a row or index using a set index value
student_score.loc[15]
# Out:
# CA1     6
# CA2    10
# CA3    10
# Name: 15, dtype: int32

# %%
# selecting multiple rows or index using a set index 
student_score.loc[[4,7,10,12]]
# Out:
#     CA1  CA2  CA3
# 4     5    5    6
# 7     7    2    4
# 10    3    1    5
# 12    8    9    3

# %%
# selecting a row or index using a default index value
student_score.iloc[15-1]
# Out:
# CA1     6
# CA2    10
# CA3    10
# Name: 15, dtype: int32

# %%
# selecting multiple rows or index using a default index
student_score.iloc[[4-1,7-1,10-1,12-1]]
# Out:
#     CA1  CA2  CA3
# 4     5    5    6
# 7     7    2    4
# 10    3    1    5
# 12    8    9    3

# %%
# selecting multiple rows or index using a default index
student_score.iloc[[3,6,9,11]]
# Out:
#     CA1  CA2  CA3
# 4     5    5    6
# 7     7    2    4
# 10    3    1    5
# 12    8    9    3

# %%
# creating a column at the end of the dataFrame
np.random.seed(2)
student_score['ExamsScore'] = np.random.randint(25,71,50).reshape(50,1)
student_score
# Out:
#     CA1  CA2  CA3  ExamsScore
# 1     9    9    7          65
# 2     3    9    8          40
# 3     3    2    6          70
# 4     5    5    6          33
# 5     8    4    7          47
# 6     5    4    8          68
# 7     7    2    4          43
# 8     6    9    5          36
# 9     7    4   10          65
# 10    3    1    5          32
# 11    3    5    2          59
# 12    8    9    3          56
# 13   10    9    8          36
# 14    2    7    9          46
# 15    6   10   10          56
# 16   10    4    1          51
# 17    1    3    9          45
# 18    9    3   10          62
# 19    7    6    7          64
# 20    7    7    4          28
# 21    9    3    2          63
# 22    5    9    2          29
# 23    7   10    6          67
# 24    2    3    5          68
# 25    8    7    5          64
# 26    6    9    4          63
# 27    1    1    6          67
# 28    8    6    1          58
# 29    9    7    6          28
# 30    2    8    5          30
# ...

# %%
# Creating a new column at any location on the dataFrame
np.random.seed(2)
student_score.insert(loc=0, value=np.random.randint(13,17,50).reshape(50,1), column='AGE')
student_score
# Out:
#     AGE  CA1  CA2  CA3  ExamsScore
# 1    13    9    9    7          65
# 2    16    3    9    8          40
# 3    14    3    2    6          70
# 4    13    5    5    6          33
# 5    15    8    4    7          47
# 6    16    5    4    8          68
# 7    15    7    2    4          43
# 8    16    6    9    5          36
# 9    13    7    4   10          65
# 10   16    3    1    5          32
# 11   15    3    5    2          59
# 12   14    8    9    3          56
# 13   16   10    9    8          36
# 14   16    2    7    9          46
# 15   14    6   10   10          56
# 16   16   10    4    1          51
# 17   16    1    3    9          45
# 18   16    9    3   10          62
# 19   15    7    6    7          64
# 20   13    7    7    4          28
# 21   13    9    3    2          63
# 22   13    5    9    2          29
# 23   14    7   10    6          67
# 24   16    2    3    5          68
# 25   16    8    7    5          64
# 26   15    6    9    4          63
# ...

# %%
# Creating a new column from existing columns
student_score['Total_Score'] = student_score['CA1'] + student_score['CA2'] + student_score['CA3'] + student_score['ExamsScore']
student_score
# Out:
#     AGE  CA1  CA2  CA3  ExamsScore  Total_Score
# 1    13    9    9    7          65           90
# 2    16    3    9    8          40           60
# 3    14    3    2    6          70           81
# 4    13    5    5    6          33           49
# 5    15    8    4    7          47           66
# 6    16    5    4    8          68           85
# 7    15    7    2    4          43           56
# 8    16    6    9    5          36           56
# 9    13    7    4   10          65           86
# 10   16    3    1    5          32           41
# 11   15    3    5    2          59           69
# 12   14    8    9    3          56           76
# 13   16   10    9    8          36           63
# 14   16    2    7    9          46           64
# 15   14    6   10   10          56           82
# 16   16   10    4    1          51           66
# 17   16    1    3    9          45           58
# 18   16    9    3   10          62           84
# 19   15    7    6    7          64           84
# ...

# %%
# Creating a new column from existing columns using a function
def grade(totalscore):
    if totalscore >= 70 and totalscore <=100:
        return 'A'
    elif totalscore >= 60 and totalscore <=69.99:
        return 'B'
    elif totalscore >= 50 and totalscore <=59.99:
        return 'C'
    elif totalscore >= 40 and totalscore <=49.99:
        return 'D'
    elif totalscore >= 30 and totalscore <=39.99:
        return 'E'
    else:
        return 'F'
student_score['GRADE'] = student_score['Total_Score'].apply(grade)
student_score
# Out:
#     AGE  CA1  CA2  CA3  ExamsScore  Total_Score GRADE
# 1    13    9    9    7          65           90     A
# 2    16    3    9    8          40           60     B
# 3    14    3    2    6          70           81     A
# 4    13    5    5    6          33           49     D
# 5    15    8    4    7          47           66     B
# 6    16    5    4    8          68           85     A
# 7    15    7    2    4          43           56     C
# 8    16    6    9    5          36           56     C
# 9    13    7    4   10          65           86     A
# 10   16    3    1    5          32           41     D
# 11   15    3    5    2          59           69     B
# 12   14    8    9    3          56           76     A
# 13   16   10    9    8          36           63     B
# 14   16    2    7    9          46           64     B
# 15   14    6   10   10          56           82     A
# 16   16   10    4    1          51           66     B
# ...

# %%
# Dropping a column or multiple columns from the dataFrame
# student_score.drop('column_name', axis= 0 or 1 inplace =True)
# student_score.drop(['A','B','D'], axis = 0 or 1 inplace =True)

# %%
student_score.head() # this will display the first 5 rows of the table
# Out:
#    AGE  CA1  CA2  CA3  ExamsScore  Total_Score GRADE
# 1   13    9    9    7          65           90     A
# 2   16    3    9    8          40           60     B
# 3   14    3    2    6          70           81     A
# 4   13    5    5    6          33           49     D
# 5   15    8    4    7          47           66     B

# %%
student_score.tail() # Tail will display the last 5 rows
# Out:
#     AGE  CA1  CA2  CA3  ExamsScore  Total_Score GRADE
# 46   14    7    4    2          40           53     C
# 47   16    9    6   10          66           91     A
# 48   15    6    5    3          70           84     A
# 49   13    8    9    8          33           58     C
# 50   13    4    5    9          42           60     B

# %%
student_score.shape # this will tell us the number of rows and columns.
# Out:
# (50, 7)

# %%
student_score.info() # info will give you full information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 50
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGE          50 non-null     int32
#  1   CA1          50 non-null     int32
#  2   CA2          50 non-null     int32
#  3   CA3          50 non-null     int32
#  4   ExamsScore   50 non-null     int32
#  5   Total_Score  50 non-null     int32
#  6   GRADE        50 non-null     object
# dtypes: int32(6), object(1)
# memory usage: 3.3+ KB

# %%
student_score.describe() # this will describe only the numerical info of the data. it provides minimun count for numericla column
# Out:
#              AGE        CA1        CA2        CA3  ExamsScore  Total_Score
# count  50.000000  50.000000  50.000000  50.000000    50.00000    50.000000
# mean   14.760000   5.780000   5.820000   5.220000    48.94000    65.760000
# std     1.204752   2.873453   2.854928   2.880547    14.53414    15.218893
# min    13.000000   1.000000   1.000000   1.000000    27.00000    39.000000
# 25%    14.000000   3.000000   4.000000   2.000000    36.00000    53.750000
# 50%    15.000000   6.000000   6.000000   5.000000    48.00000    65.000000
# 75%    16.000000   8.000000   8.750000   8.000000    63.75000    77.750000
# max    16.000000  10.000000  10.000000  10.000000    70.00000    91.000000

# %%
# transpose this will turn the rows into column and column to rows
student_score.head().transpose()
# Out:
#               1   2   3   4   5
# AGE          13  16  14  13  15
# CA1           9   3   3   5   8
# CA2           9   9   2   5   4
# CA3           7   8   6   6   7
# ExamsScore   65  40  70  33  47
# Total_Score  90  60  81  49  66
# GRADE         A   B   A   D   B

# %%
# to get the column names 
student_score.columns
# Out:
# Index(['AGE', 'CA1', 'CA2', 'CA3', 'ExamsScore', 'Total_Score', 'GRADE'], dtype='object')

# %%
# To rename column
student_score.rename({'CA1':'FIRST CA', 'CA2': 'SECOND CA', 'CA3': 'THIRD CA'}, axis=1, inplace=True)
student_score.head()
# Out:
#    AGE  FIRST CA  SECOND CA  THIRD CA  ExamsScore  Total_Score GRADE
# 1   13         9          9         7          65           90     A
# 2   16         3          9         8          40           60     B
# 3   14         3          2         6          70           81     A
# 4   13         5          5         6          33           49     D
# 5   15         8          4         7          47           66     B

# %%
# to change/replace any value from the table
student_score['AGE'].loc[1] = 15
student_score.head()
# Out:
# C:\Users\H P PC\AppData\Local\Temp\ipykernel_5924\3420263306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_score['AGE'].loc[1] = 15
#    AGE  FIRST CA  SECOND CA  THIRD CA  ExamsScore  Total_Score GRADE
# 1   15         9          9         7          65           90     A
# 2   16         3          9         8          40           60     B
# 3   14         3          2         6          70           81     A
# 4   13         5          5         6          33           49     D
# 5   15         8          4         7          47           66     B

# %%
student_score['GRADE'].unique() # This will bring out all the unique values on the table
# Out:
# array(['A', 'B', 'D', 'C', 'E'], dtype=object)

# %%
student_score['GRADE'].nunique() # This will give you the number of the unique values
# Out:
# 5

# %%
student_score['GRADE'].value_counts() # This will give the count for each of the unique values
# Out:
# GRADE
# A    21
# C    10
# B     9
# D     9
# E     1
# Name: count, dtype: int64

# %%
df = pd.read_csv('sample_pivot.csv')
df.head()
# Out:
#         Date Region                 Type  Units  Sales
# 0  7/11/2020   East  Children's Clothing   18.0    306
# 1  9/23/2020  North  Children's Clothing   14.0    448
# 2   4/2/2020  South     Women's Clothing   17.0    425
# 3  2/28/2020   East  Children's Clothing   26.0    832
# 4  3/19/2020   West     Women's Clothing    3.0     33

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1000 non-null   object
#  1   Region  1000 non-null   object
#  2   Type    1000 non-null   object
#  3   Units   911 non-null    float64
#  4   Sales   1000 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Date       0
# Region     0
# Type       0
# Units     89
# Sales      0
# dtype: int64

# %%
# Different fillin techniques:

# forward fill
df.tail()
# Out:
#            Date Region                 Type  Units  Sales
# 995   2/11/2020   East  Children's Clothing   35.0    735
# 996  12/25/2020  North       Men's Clothing    NaN   1155
# 997   8/31/2020  South       Men's Clothing   13.0    208
# 998   8/23/2020  South     Women's Clothing   17.0    493
# 999   8/17/2020  North     Women's Clothing   25.0    300

# %%
df1 = df.copy()
df1.fillna(method = 'ffill', inplace=True) # fillna mean fill not available. ffill means forward fill
df1.tail()
# Out:
# C:\Users\H P PC\AppData\Local\Temp\ipykernel_5924\3154010155.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method = 'ffill', inplace=True)
#            Date Region                 Type  Units  Sales
# 995   2/11/2020   East  Children's Clothing   35.0    735
# 996  12/25/2020  North       Men's Clothing   35.0   1155
# 997   8/31/2020  South       Men's Clothing   13.0    208
# 998   8/23/2020  South     Women's Clothing   17.0    493
# 999   8/17/2020  North     Women's Clothing   25.0    300

# %%
# backward
df1 = df.copy()
df1.fillna(method = 'bfill', inplace=True) # bfill means backward fill
df1.tail()
# Out:
# C:\Users\H P PC\AppData\Local\Temp\ipykernel_5924\1473137693.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method = 'bfill', inplace=True) # bfill means backward fill
#            Date Region                 Type  Units  Sales
# 995   2/11/2020   East  Children's Clothing   35.0    735
# 996  12/25/2020  North       Men's Clothing   13.0   1155
# 997   8/31/2020  South       Men's Clothing   13.0    208
# 998   8/23/2020  South     Women's Clothing   17.0    493
# 999   8/17/2020  North     Women's Clothing   25.0    300

# %%
# using ststistical method
df2 = df.copy()
df2['Units'].fillna(df2['Units'].mean(),inplace=True)
df2.tail()
# Out:
#            Date Region                 Type      Units  Sales
# 995   2/11/2020   East  Children's Clothing  35.000000    735
# 996  12/25/2020  North       Men's Clothing  19.638858   1155
# 997   8/31/2020  South       Men's Clothing  13.000000    208
# 998   8/23/2020  South     Women's Clothing  17.000000    493
# 999   8/17/2020  North     Women's Clothing  25.000000    300

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1000 non-null   object
#  1   Region  1000 non-null   object
#  2   Type    1000 non-null   object
#  3   Units   1000 non-null   float64
#  4   Sales   1000 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
# dropping missing values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Date      0
# Region    0
# Type      0
# Units     0
# Sales     0
# dtype: int64
